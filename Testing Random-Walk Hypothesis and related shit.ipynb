# %%
import datetime
import matplotlib.pyplot as plt

import pandas as pd
import pandas.io.data
from pandas import Series, DataFrame
pd.__version__
# Out:
# '0.13.1'

# %%
# %matplotlib inline

# %%
NDX = pd.io.data.get_data_yahoo('^NDX', 
                                 start=datetime.datetime(1994, 12, 1), 
                                 end=datetime.datetime(2014, 12, 1))

FTSE = pd.io.data.get_data_yahoo('^FTSE', 
                                 start=datetime.datetime(1994, 12, 1), 
                                 end=datetime.datetime(2014, 12, 1))

GSPC = pd.io.data.get_data_yahoo('^GSPC', 
                                 start=datetime.datetime(1994, 12, 1), 
                                 end=datetime.datetime(2014, 12, 1))

# %% [markdown]
# Load 20 years of daily prices of FTSE 100, S&P 500 and NASDAQ-100.
# They are plotted below.
# (Green: FTSE 100; Blue: NASDAQ-100; Red: S&P 500)

# %%
NDX_1d_prices = NDX['Adj Close']
NDX_1d_prices.plot()

FTSE_1d_prices = FTSE['Adj Close']
FTSE_1d_prices.plot()

GSPC_1d_prices = GSPC['Adj Close']
GSPC_1d_prices.plot()

# %% [markdown]
# Shift time index by -1.

# %%
import statsmodels.api as sm

NDX_1d_prices_shifted = NDX_1d_prices.shift().dropna()
FTSE_1d_prices_shifted = FTSE_1d_prices.shift().dropna()
GSPC_1d_prices_shifted = GSPC_1d_prices.shift().dropna()

# %% [markdown]
# Here are plotted autocorrelation functions for all three time series in order to determine if these time series are weakly dependent. No fckin idea how to tell though => KUBO HELP ME, HELP ME, I AM LOST WITHOUT YOU :D
#
# (colors same as before)

# %%
plt.plot(sm.tsa.stattools.acf(NDX_1d_prices))
plt.plot(sm.tsa.stattools.acf(FTSE_1d_prices))
plt.plot(sm.tsa.stattools.acf(GSPC_1d_prices))
plt.show()

# %% [markdown]
# Estimate AR(1) processes for all three stock indexes. Results are in the tables below.

# %%
y = NDX_1d_prices[1:]
X = NDX_1d_prices.shift().dropna()
X = sm.add_constant(X) 

print 'for NASDAQ:'

est = sm.OLS(y, X)
est = est.fit()
est.summary()
# Out:
# for NASDAQ:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Adj Close   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 2.534e+06
# Date:                Tue, 13 Jan 2015   Prob (F-statistic):               0.00
# Time:                        23:15:20   Log-Likelihood:                -25667.
# No. Observations:                5035   AIC:                         5.134e+04
# Df Residuals:                    5033   BIC:                         5.135e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.6982      1.284      1.323      0.186        -0.819     4.215
# Adj Close      0.9995      0.001   1591.894      0.000         0.998     1.001
# ==============================================================================
# Omnibus:                     1061.940   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            40859.932
# Skew:                           0.090   Prob(JB):                         0.00
# Kurtosis:                      16.955   Cond. No.                     4.70e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y = FTSE_1d_prices[1:]
X = FTSE_1d_prices.shift().dropna()
X = sm.add_constant(X) 

print 'for FTSE 100:'
est = sm.OLS(y, X)
est = est.fit()
est.summary()
# Out:
# for FTSE 100:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Adj Close   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 1.369e+06
# Date:                Tue, 13 Jan 2015   Prob (F-statistic):               0.00
# Time:                        23:15:43   Log-Likelihood:                -28132.
# No. Observations:                5098   AIC:                         5.627e+04
# Df Residuals:                    5096   BIC:                         5.628e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         12.2589      4.595      2.668      0.008         3.250    21.268
# Adj Close      0.9978      0.001   1170.102      0.000         0.996     0.999
# ==============================================================================
# Omnibus:                      486.305   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3190.935
# Skew:                          -0.185   Prob(JB):                         0.00
# Kurtosis:                       6.858   Cond. No.                     2.93e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.93e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y = GSPC_1d_prices[1:]
X = GSPC_1d_prices.shift().dropna()
X = sm.add_constant(X) 

print 'for S&P 500:'

est = sm.OLS(y, X)
est = est.fit()
est.summary()
# Out:
# for S&P 500:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Adj Close   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 2.824e+06
# Date:                Tue, 13 Jan 2015   Prob (F-statistic):               0.00
# Time:                        23:16:35   Log-Likelihood:                -20614.
# No. Observations:                5119   AIC:                         4.123e+04
# Df Residuals:                    5117   BIC:                         4.124e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          1.1097      0.725      1.530      0.126        -0.312     2.531
# Adj Close      0.9993      0.001   1680.444      0.000         0.998     1.000
# ==============================================================================
# Omnibus:                      657.426   Durbin-Watson:                   2.132
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5816.955
# Skew:                          -0.298   Prob(JB):                         0.00
# Kurtosis:                       8.188   Cond. No.                     4.66e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.66e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Here belong some conclusions about that horseshit from regressions...
#
# (DO WE WANT TO TEST INDIVIDUAL STOCKS ALSO? IF WE DO, WHICH?)

# %%
NDX_1d_returns = NDX['Adj Close'].pct_change().dropna()
FTSE_1d_returns = NDX['Adj Close'].pct_change().dropna()
GSPC_1d_returns = NDX['Adj Close'].pct_change().dropna()

# %%
NDX_1d_returns.plot()

# %%
NDX_1d_returns[1000:2000].hist(bins=100), 
NDX_1d_returns[2000:3000].hist(bins=100)

# %% [markdown]
# Probably not stationary, because of VARIANCE.

# %%
NDX_1d_returns.shift().dropna().describe(), NDX_1d_returns[1:5035].describe()
# Out:
# (count    5034.000000
# mean        0.000652
# std         0.018864
# min        -0.105195
# 25%        -0.008098
# 50%         0.001262
# 75%         0.009422
# max         0.187713
# Name: Adj Close, dtype: float64,
#  count    5034.000000
# mean        0.000648
# std         0.018864
# min        -0.105195
# 25%        -0.008119
# 50%         0.001253
# 75%         0.009421
# max         0.187713
# Name: Adj Close, dtype: float64)

# %% [markdown]
# Test EMH using asymptotic analysis. (Hypothesis formulated only as AR(1) process)

# %%
import statsmodels.api as sm

# %%
y = NDX_1d_returns[1:5035]
X = NDX_1d_returns.shift().dropna()
X = sm.add_constant(X)  # Adds a constant term to the predictor
X.head()
# Out:
#             const  Adj Close
# Date
# 1994-12-05      1   0.011014
# 1994-12-06      1   0.001667
# 1994-12-07      1  -0.006779
# 1994-12-08      1  -0.010576
# 1994-12-09      1  -0.023879
#
# [5 rows x 2 columns]

# %%
est = sm.OLS(y, X)
est = est.fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Adj Close   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     16.90
# Date:                Wed, 31 Dec 2014   Prob (F-statistic):           3.99e-05
# Time:                        17:00:43   Log-Likelihood:                 12854.
# No. Observations:                5034   AIC:                        -2.570e+04
# Df Residuals:                    5032   BIC:                        -2.569e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.0007      0.000      2.581      0.010         0.000     0.001
# Adj Close     -0.0579      0.014     -4.111      0.000        -0.085    -0.030
# ==============================================================================
# Omnibus:                      662.160   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6867.934
# Skew:                           0.235   Prob(JB):                         0.00
# Kurtosis:                       8.703   Cond. No.                         53.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# We cannot reject H_0(EMH).
